# %%
#import dependencies
import os
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
#import the regular quotes csv file
quotes_path = os.path.join('appdata', 'quotes.csv')

#read in the quotes csv
quotes = pd.read_csv(quotes_path)

# %%
#view quotes df
quotes
# Out:
#            created   fee  amount                   user_id  \
# 0    1565379085555  1505    2408  5d44c110dd21cc0017773517
# 1    1565384470886  1417    2267  5d44c110dd21cc0017773517
# 2    1565384504906  1417    2267  5d44c110dd21cc0017773517
# 3    1565384670193  1433    2150  5d44c110dd21cc0017773517
# 4    1565384715472  1417    2126  5d44c110dd21cc0017773517
# ..             ...   ...     ...                       ...
# 972  1612900142488   656     722  5f1df4da4b7a120017288534
# 973  1612900154903   656     722  5f1df4da4b7a120017288534
# 974  1612902806774   637     701  5f1df4da4b7a120017288534
# 975  1612902827687   637     701  5f1df4da4b7a120017288534
# 976  1612992350415   600     660  5fa46e4f8cceb80017db6845
#
#                              pickup_address  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# ...

# %%
#import custom quotes csv file
custom_path = os.path.join('appdata', 'customquotes.csv')

#read in the custom quotes csv
custom = pd.read_csv(custom_path)

# %%
#view custom_df
custom
# Out:
#                                        pickup_address  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 453        529 Central Avenue, Pacific Grove, CA, USA
# 454  529 Central Avenue, Pacific Grove, CA 93950, USA
# 455  529 Central Avenue, Pacific Grove, CA 93950, USA
# 456  529 Central Avenue, Pacific Grove, CA 93950, USA
# 457  529 Central Avenue, Pacific Grove, CA 93950, USA
#
#                                        dropoff_address  amount       created
# 0                                                  NaN     868  1.610000e+12
# 1                                                  NaN    1033  1.610000e+12
# 2                                                  NaN    1033  1.610000e+12
# ...

# %%
#create boxplot of regular and custom quotes amount
fig, ax = plt.subplots(figsize=(10,10))
ax.boxplot([quotes['amount'], custom['amount']], labels=('Regular', 'Custom'))
ax.set_title('Regular/Custom Quotes Amount')
ax.set_ylabel('Amount($)')
# Out:
# Text(0, 0.5, 'Amount($)')
